# %%
#Adjust the working folder
import sys
import os
#print(globals())
file_folder = globals()['_dh'][0]
wk_dir = os.path.dirname(file_folder)
os.chdir(wk_dir)

import pandas as pd

from code_felix.core.config import *
from code_felix.core.feature import *
from file_cache.utils.util_log import *

import matplotlib.pyplot as plt


plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号

# %%
df = get_word2_id_2vec()
# Out:
# 2019-01-02 17:17:54,718 util_log.py[41] INFO get_word2_id_2vec begin with(0 paras) :[], []
# 2019-01-02 17:17:54,724 util_log.py[41] INFO get_word2_id_2vec begin with(0 paras) :[], []
# 2019-01-02 17:17:54,726 cache.py[38] DEBUG Can not find cache from file:./cache/get_word2_id_2vec==.h5
# 2019-01-02 17:17:54,731 util_log.py[41] INFO get_word_freqs begin with(0 paras) :[], []
# Building prefix dict from the default dictionary ...
# 2019-01-02 17:17:54,753 __init__.py[111] DEBUG Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/d2/vq91lnt11m13m84s18dzdm8r0000gn/T/jieba.cache
# 2019-01-02 17:17:54,763 __init__.py[131] DEBUG Loading model from cache /var/folders/d2/vq91lnt11m13m84s18dzdm8r0000gn/T/jieba.cache
# Loading model cost 0.839 seconds.
# 2019-01-02 17:17:55,600 __init__.py[163] DEBUG Loading model cost 0.839 seconds.
# Prefix dict has been built succesfully.
# ...

# %%
dataset_test = pd.read_csv('./input/data_train.csv', encoding='gb18030', delimiter='\t', header=None)
dataset_test.iloc[:,3].hist()
plt.show()

# %%
df.head()
# Out:
#     freqs word  id         0         1         2         3         4  \
# 0       0  PAD   0       NaN       NaN       NaN       NaN       NaN
# 1       0  UNK   1       NaN       NaN       NaN       NaN       NaN
# 2  148605    ，   2       NaN       NaN       NaN       NaN       NaN
# 3   77984    的   3  0.095636 -0.075679 -0.026553  0.128607  0.047103
# 4   36485    。   4  0.058383 -0.121455  0.000360  0.119481  0.044204
#
#           5         6    ...          190       191       192       193  \
# 0       NaN       NaN    ...          NaN       NaN       NaN       NaN
# 1       NaN       NaN    ...          NaN       NaN       NaN       NaN
# 2       NaN       NaN    ...          NaN       NaN       NaN       NaN
# 3  0.045679  0.021629    ...     0.127076  0.038966  0.003183 -0.022372
# 4  0.004898 -0.013096    ...     0.123798  0.028523  0.022717 -0.041538
#
#         194       195       196       197       198       199
# ...

# %%
get_word_freqs()
# Out:
# 2019-01-02 17:11:33,913 util_log.py[41] INFO get_word_freqs begin with(0 paras) :[], []
# 2019-01-02 17:11:44,454 util_log.py[49] INFO get_word_freqs cost   10.54 sec:(0 paras)([], []), return:DataFrame, end
#         freqs     word     id
# 77708       0      PAD      0
# 77709       0      UNK      1
# 0      148605        ，      2
# 1       54310        的      3
# 2       36485        。      4
# 3       22499        了      5
# 4       14998        ！      6
# 5       12643               7
# 6        8705        也      8
# 7        7792        是      9
# 8        6443        我     10
# 9        6250        在     11
# 10       6048        都     12
# 11       5805        还     13
# 12       5647        就     14
# 13       4741       还是     15
# 14       4659        有     16
# 15       4642       不错     17
# 16       4064        和     18
# 17       3952       医院     19
# 18       3835       我们     20
# 19       3696       很多     21
# 20       3670       一个     22
# ...

# %%
idvec = get_id2vec()
idvec
# Out:
# 2019-01-02 17:01:35,713 utils.py[418] INFO loading Word2VecKeyedVectors object from ./output/mini.kv
# 2019-01-02 17:01:35,717 smart_open_lib.py[176] DEBUG {'kw': {}, 'mode': 'rb', 'uri': './output/mini.kv'}
# 2019-01-02 17:01:36,518 utils.py[456] INFO loading vectors from ./output/mini.kv.vectors.npy with mmap=r
# 2019-01-02 17:01:36,532 utils.py[487] INFO setting ignored attribute vectors_norm to None
# 2019-01-02 17:01:36,535 utils.py[424] INFO loaded ./output/mini.kv
# 2019-01-02 17:01:36,537 keyedvectors.py[1360] INFO precomputing L2-norms of word weight vectors
# /Users/lali2/dev/python/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:29: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
# /Users/lali2/dev/python/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:38: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
# ...

# %%
   

df = get_word2id_id2vec()
df.head()
# Out:
# 2019-01-02 17:04:47,505 util_log.py[41] INFO get_word_freqs begin with(0 paras) :[], []
# 2019-01-02 17:05:03,068 util_log.py[49] INFO get_word_freqs cost   15.56 sec:(0 paras)([], []), return:DataFrame, end
# 2019-01-02 17:05:03,070 util_log.py[41] INFO get_id2vec begin with(0 paras) :[], []
# 2019-01-02 17:05:03,071 utils.py[418] INFO loading Word2VecKeyedVectors object from ./output/mini.kv
# 2019-01-02 17:05:03,073 smart_open_lib.py[176] DEBUG {'kw': {}, 'mode': 'rb', 'uri': './output/mini.kv'}
# 2019-01-02 17:05:04,191 utils.py[456] INFO loading vectors from ./output/mini.kv.vectors.npy with mmap=r
# 2019-01-02 17:05:04,204 utils.py[487] INFO setting ignored attribute vectors_norm to None
# 2019-01-02 17:05:04,207 utils.py[424] INFO loaded ./output/mini.kv
# 2019-01-02 17:05:04,210 keyedvectors.py[1360] INFO precomputing L2-norms of word weight vectors
# ...

# %%
df.loc[pd.isna(df[0])]

#word_vectors.similar_by_word('探望')
# Out:
#         freqs     word     id   0   1   2   3   4   5   6 ...   190  191  192  \
# 0           0      PAD      0 NaN NaN NaN NaN NaN NaN NaN ...   NaN  NaN  NaN
# 1           0      UNK      1 NaN NaN NaN NaN NaN NaN NaN ...   NaN  NaN  NaN
# 2      148605        ，      2 NaN NaN NaN NaN NaN NaN NaN ...   NaN  NaN  NaN
# 7       12643               7 NaN NaN NaN NaN NaN NaN NaN ...   NaN  NaN  NaN
# 40       2254       \t     40 NaN NaN NaN NaN NaN NaN NaN ...   NaN  NaN  NaN
# 707       175      APP    707 NaN NaN NaN NaN NaN NaN NaN ...   NaN  NaN  NaN
# 739       169      DIY    739 NaN NaN NaN NaN NaN NaN NaN ...   NaN  NaN  NaN
# 1721       68        O   1721 NaN NaN NaN NaN NaN NaN NaN ...   NaN  NaN  NaN
# 2317       48        C   2317 NaN NaN NaN NaN NaN NaN NaN ...   NaN  NaN  NaN
# 2454       45       OK   2454 NaN NaN NaN NaN NaN NaN NaN ...   NaN  NaN  NaN
# 2510       44        N   2510 NaN NaN NaN NaN NaN NaN NaN ...   NaN  NaN  NaN
# ...

# %%
fname = "./output/mini.kv"

from gensim.models import KeyedVectors
word_vectors = KeyedVectors.load(fname, mmap='r')
ordered_vocab = [(term, voc.index, voc.count) for term, voc in word_vectors.wv.vocab.items()]

# sort by the term counts, so the most common terms appear first
ordered_vocab = sorted(ordered_vocab, key=lambda k: -k[2])

# unzip the terms, integer indices, and counts into separate lists
ordered_terms, term_indices, term_counts = zip(*ordered_vocab)
# print(ordered_terms)
# create a DataFrame with the food2vec vectors as data,
# and the terms as row labels
word_vectors = pd.DataFrame(word_vectors.wv.syn0norm[term_indices, :], index=ordered_terms)

word_vectors
# Out:
# 2019-01-02 16:55:08,032 utils.py[418] INFO loading Word2VecKeyedVectors object from ./output/mini.kv
# 2019-01-02 16:55:08,038 smart_open_lib.py[176] DEBUG {'kw': {}, 'mode': 'rb', 'uri': './output/mini.kv'}
# 2019-01-02 16:55:08,681 utils.py[456] INFO loading vectors from ./output/mini.kv.vectors.npy with mmap=r
# 2019-01-02 16:55:08,696 utils.py[487] INFO setting ignored attribute vectors_norm to None
# 2019-01-02 16:55:08,699 utils.py[424] INFO loaded ./output/mini.kv
# /Users/lali2/dev/python/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """
# /Users/lali2/dev/python/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:15: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   from ipykernel import kernelapp as app
# ...

# %%
len(word_vectors.wv.syn0norm)
# Out:
# /Users/lali2/dev/python/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.
# /Users/lali2/dev/python/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `syn0norm` (Attribute will be removed in 4.0.0, use self.wv.vectors_norm instead).
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-130-bd36feac4154> in <module>()
# ----> 1 len(word_vectors.wv.syn0norm)
#
# TypeError: object of type 'NoneType' has no len()

# %%
word_vectors['探望']
# Out:
# memmap([ 0.21461999,  0.139884  ,  0.391754  ,  0.231987  ,  0.11961   ,
#         -0.31259799, -0.102125  ,  0.020797  ,  0.361761  , -0.09875   ,
#         -0.047344  ,  0.12978899,  0.219998  , -0.407498  ,  0.161724  ,
#         -0.118959  , -0.19262899, -0.294972  , -0.136594  , -0.199864  ,
#          0.082437  ,  0.378111  ,  0.022619  ,  0.093166  ,  0.104366  ,
#          0.57152098, -0.243688  ,  0.44615701,  0.35987699,  0.052411  ,
#         -0.06698   ,  0.102023  ,  0.17807201,  0.049176  , -0.30131701,
#         -0.044619  ,  0.053053  ,  0.23609   , -0.085294  , -0.035479  ,
#          0.33512801, -0.32636601, -0.090003  ,  0.74466902, -0.34595901,
#         -0.213992  , -0.287085  , -0.38124299,  0.087105  ,  0.069898  ,
#         -0.175255  , -0.23327801, -0.17242301,  0.10459   ,  0.283894  ,
#          0.35463399,  0.032908  ,  0.140956  , -0.14814   ,  0.204862  ,
#         -0.186671  ,  0.242083  ,  0.620884  ,  0.150089  ,  0.072815  ,
# ...

# %%
import socket
host_name = socket.gethostname()
host_name
# Out:
# 'LALI2-M-G0MD'
