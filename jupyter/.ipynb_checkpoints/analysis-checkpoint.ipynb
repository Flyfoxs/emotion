# %% [markdown]
# # Baidu Emotion

# %%
#Adjust the working folder
import sys
import os
#print(globals())
file_folder = globals()['_dh'][0]
wk_dir = os.path.dirname(file_folder)
os.chdir(wk_dir)

import pandas as pd
# from code_felix.utils_.util_pandas import *
from code_felix.core.config import *
# from code_felix.feature.category import *
import matplotlib.pyplot as plt
# from code_felix.feature.read_file import _get_transaction, _summary_card_trans_col

#trans_new =  get_trans(trans_new_file)

plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号

# %%
# https://www.kaggle.com/eray1yildiz/using-lstms-with-attention-for-emotion-recognition/notebook
# https://ai.tencent.com/ailab/nlp/embedding.html
#blog : https://blog.csdn.net/sinat_26917383/article/details/83999966

#如何利用词库,增强jieba: https://blog.csdn.net/chinatelecom08/article/details/84588071

# %%
import jieba
jieba.load_userdict(jieba_dict)

text = "欧阳建国是创新办主任也是欢聚时代公司云计算方面的专家"
#text = "真的挺好用, 吃不上"

# jieba.cut() 方法接受两个输入参数: 
# 需要分词的字符串
# cut_all 参数用来控制是否采用全模式

# 精确模式，默认模式就是精确模式
seg_list = jieba.cut(text, cut_all = False)
print('Default Mode:\n' + '/' .join(seg_list))

# 全模式
seg_list = jieba.cut(text, cut_all = True)
print( "Full Mode:\n" + '/' .join(seg_list))

# jieba.cut_for_search() 方法接受一个参数：
# 需要分词的字符串
# 该方法适合用于搜索引擎构建倒排索引的分词，粒度比较细

# 搜索引擎模式
seg_list = jieba.cut_for_search(text)
print('Research Mode:\n' + '/'.join(seg_list))
# Out:
# Building prefix dict from the default dictionary ...
# 2018-12-31 23:58:44,482 __init__.py[111] DEBUG Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/d2/vq91lnt11m13m84s18dzdm8r0000gn/T/jieba.cache
# 2018-12-31 23:58:44,489 __init__.py[131] DEBUG Loading model from cache /var/folders/d2/vq91lnt11m13m84s18dzdm8r0000gn/T/jieba.cache
# Loading model cost 0.763 seconds.
# 2018-12-31 23:58:45,251 __init__.py[163] DEBUG Loading model cost 0.763 seconds.
# Prefix dict has been built succesfully.
# 2018-12-31 23:58:45,254 __init__.py[164] DEBUG Prefix dict has been built succesfully.
# Default Mode:
# 欧阳/建国/是/创新/办/主任/也是/欢聚/时代/公司/云/计算/方面/的/专家
# Full Mode:
# 欧阳/欧阳建/建国/国是/创新/办/主任/也是/欢聚/时代/代公/公司/云/计算/方面/的/专家
# Research Mode:
# 欧阳/建国/是/创新/办/主任/也是/欢聚/时代/公司/云/计算/方面/的/专家

# %%
jieba.cut?

# %%
import jieba


print('Begin success')
jieba.load_userdict('./input/jieba.txt')

print('Load success')

train= pd.read_csv(train_file, encoding='gb18030', delimiter='\t', header=None)
train = train[:20]
train.head()
train['jieba'] = train.iloc[:,2].apply(lambda text: ' '.join(jieba.cut(str(text), cut_all = False)))
train['jieba_len'] = train['jieba'].apply(lambda text: len(text.split(' ')))
train.head()

import collections
count = collections.Counter()

for text in train['jieba'].values:
    for word in text.split(' '):
        count[word] +=1

print(len(count))
print(count)

# %%
jieba.load_userdict('./input/jieba.txt')
dir(jieba.FREQ)

# %%
list(jieba.dt.FREQ.keys())[:10]

# %%
import numpy as np
import gensim
from code_felix.core.config import *

def compute_ngrams(word, min_n, max_n):
    #BOW, EOW = ('<', '>')  # Used by FastText to attach to all words as prefix and suffix
    extended_word =  word
    ngrams = []
    for ngram_length in range(min_n, min(len(extended_word), max_n) + 1):
        for i in range(0, len(extended_word) - ngram_length + 1):
            ngrams.append(extended_word[i:i + ngram_length])
    return list(set(ngrams))


def wordVec(word,wv_from_text,min_n = 1, max_n = 3):
    '''
    ngrams_single/ngrams_more,主要是为了当出现oov的情况下,最好先不考虑单字词向量
    '''
    # 确认词向量维度
    word_size = wv_from_text.wv.syn0[0].shape[0]   
    # 计算word的ngrams词组
    ngrams = compute_ngrams(word,min_n = min_n, max_n = max_n)
    # 如果在词典之中，直接返回词向量
    if word in wv_from_text.wv.vocab.keys():
        return wv_from_text[word]
    else:  
        # 不在词典的情况下
        word_vec = np.zeros(word_size, dtype=np.float32)
        ngrams_found = 0
        ngrams_single = [ng for ng in ngrams if len(ng) == 1]
        ngrams_more = [ng for ng in ngrams if len(ng) > 1]
        # 先只接受2个单词长度以上的词向量
        for ngram in ngrams_more:
            if ngram in wv_from_text.wv.vocab.keys():
                word_vec += wv_from_text[ngram]
                ngrams_found += 1
                #print(ngram)
        # 如果，没有匹配到，那么最后是考虑单个词向量
        if ngrams_found == 0:
            for ngram in ngrams_single:
                word_vec += wv_from_text[ngram]
                ngrams_found += 1
        if word_vec.any():
            return word_vec / max(1, ngrams_found)
        else:
            raise KeyError('all ngrams for word %s absent from model' % word)
 



def load_embedding(path):
    embedding_index = {}
    f = open(path,encoding='utf8')
    for index,line in enumerate(f):
        if index == 0:
            continue
        values = line.split(' ')
        word = values[0]
        coefs = np.asarray(values[1:],dtype='float32')
        embedding_index[word] = coefs
    f.close()

    return embedding_index




import jieba
def gen_mini_embedding(full, mini, file, cut_all=True):   

    input_text= pd.read_csv(file, encoding='gb18030', delimiter='\t', header=None)
    input_text = input_text[:200]
    input_text.head()
    input_text['jieba'] = input_text.iloc[:,2].apply(lambda text: ' '.join(jieba.cut(str(text), cut_all)))
    input_text['jieba_len'] = input_text['jieba'].apply(lambda text: len(text.split(' ')))
    for text in input_text['jieba'].values:
        for word in text.strip().split(' '):
            if word in full and word not in mini:
                mini[word] = full[word]
            elif word not in full and len(word) == 1:
                #print(f'Canot find vec for:{word}')
                pass
            elif word not in full and len(word) >1:
                print(f'Canot find vec for:{len(word)}, {word}')
            else:
                pass
    return mini


#compute_ngrams('搞来搞去', 1, 3)
#wordVec('搞来搞去', embed, 1, 3)   



embed = load_embedding(word2vec_model)
vector_size=200
mini = gensim.models.keyedvectors.Word2VecKeyedVectors(vector_size)
mini = gen_mini_embedding(embed, mini, train_file )

mini = gen_mini_embedding(embed, mini, test_file )

from gensim.test.utils import get_tmpfile
fname = "./output/mini.kv"
mini.save(fname)
# Out:
# Canot find vec for:2, 三方
# Canot find vec for:2, 方平
# Canot find vec for:4, 方便管理
# Canot find vec for:2, 烤鸭
# Canot find vec for:2, 标明
# Canot find vec for:2, 越来
# Canot find vec for:2, 作过
# Canot find vec for:3, 叫外卖
# Canot find vec for:2, 辣味
# Canot find vec for:3, 叫外卖
# Canot find vec for:2, 送达
# Canot find vec for:2, 分毫
# Canot find vec for:4, 分毫不差
# Canot find vec for:6, hellip
# Canot find vec for:6, hellip
# Canot find vec for:2, 啊哈
# Canot find vec for:4, 品种齐全
# Canot find vec for:2, 上菜
# Canot find vec for:4, 服务态度
# Canot find vec for:2, 单系
# Canot find vec for:3, 多一些
# Canot find vec for:2, 定点
# Canot find vec for:2, 上菜
# Canot find vec for:3, 没得说
# Canot find vec for:2, 刺身
# Canot find vec for:2, 常新
# Canot find vec for:2, 有求
# Canot find vec for:4, 有求必应
# Canot find vec for:2, 必应
# Canot find vec for:2, 越来
# Canot find vec for:4, 努力提高
# Canot find vec for:2, 扇贝
# Canot find vec for:2, 收银
# Canot find vec for:2, 上菜
# Canot find vec for:2, 色香
# Canot find vec for:3, 色香味
# Canot find vec for:2, 俱全
# Canot find vec for:2, 里加
# Canot find vec for:2, 青豆
# Canot find vec for:2, 香脆
# Canot find vec for:2, 不忙
# Canot find vec for:2, 菜店
# Canot find vec for:2, 不忙
# Canot find vec for:2, 烤鸭
# Canot find vec for:3, 餐饮网
# Canot find vec for:2, 适中
# Canot find vec for:3, 好几个
# Canot find vec for:2, 应答
# Canot find vec for:3, 自助餐
# Canot find vec for:2, 上菜
# Canot find vec for:2, 份量
# Canot find vec for:2, 鱼头
# Canot find vec for:2, 鱼汁
# Canot find vec for:2, 坑人
# Canot find vec for:2, 竹笋
# Canot find vec for:2, 零星
# Canot find vec for:2, 根竹
# Canot find vec for:2, 竹笋
# Canot find vec for:4, 文字游戏
# Canot find vec for:6, hellip
# Canot find vec for:6, hellip
# Canot find vec for:2, 坑人
# Canot find vec for:3, seo
# Canot find vec for:2, 面有
# Canot find vec for:2, 改改
# Canot find vec for:2, 扇贝
# Canot find vec for:2, 有生
# Canot find vec for:3, 串串香
# Canot find vec for:3, 棒极了
# Canot find vec for:2, 锅盖
# Canot find vec for:3, 串串香
# Canot find vec for:2, 整套
# Canot find vec for:2, 回龙
# Canot find vec for:3, 回龙观
# Canot find vec for:2, 马门
# Canot find vec for:2, 门帘
# Canot find vec for:2, 成对
# Canot find vec for:2, 间色
# Canot find vec for:2, 真会
# Canot find vec for:3, 十几个
# Canot find vec for:2, 总觉
# Canot find vec for:3, 好几个
# Canot find vec for:2, 如以
# Canot find vec for:3, 招牌菜
# Canot find vec for:3, 吃不出
# Canot find vec for:4, 吃不出来
# Canot find vec for:2, 辣味
# Canot find vec for:2, 肯德
# Canot find vec for:4, 食品卫生
# Canot find vec for:3, 经常性
# Canot find vec for:2, 常性
# Canot find vec for:2, 天人
# Canot find vec for:2, 锅底
# Canot find vec for:2, 配菜
# Canot find vec for:4, 相当可观
# Canot find vec for:2, 小成
# Canot find vec for:3, 价比高
# Canot find vec for:2, 比高
# Canot find vec for:2, 肘子
# Canot find vec for:2, 包间
# Canot find vec for:3, 肉夹馍
# Canot find vec for:2, 凉皮
# Canot find vec for:2, 西口
# Canot find vec for:2, 下流
# Canot find vec for:2, 去秋
# Canot find vec for:4, 服务态度
# Canot find vec for:3, 没得说
# Canot find vec for:2, 十瓶
# Canot find vec for:2, 几瓶
# Canot find vec for:3, 260
# Canot find vec for:2, 会管
# Canot find vec for:2, 常来
# Canot find vec for:2, 赢取
# Canot find vec for:3, 挺好吃
# Canot find vec for:2, 锅底
# Canot find vec for:2, 底里
# Canot find vec for:2, 放点
# Canot find vec for:2, 一服
# Canot find vec for:4, 赚黑心钱
# Canot find vec for:2, 黑心
# Canot find vec for:3, 黑心钱
# Canot find vec for:2, 提心
# Canot find vec for:4, 提心吊胆
# Canot find vec for:3, 肉夹馍
# Canot find vec for:3, 肉夹馍
# Canot find vec for:4, 各不相同
# Canot find vec for:2, 法理
# Canot find vec for:2, 肉包
# Canot find vec for:3, 肉包子
# Canot find vec for:2, 淋巴
# Canot find vec for:3, 手指甲
# Canot find vec for:3, 5cm
# Canot find vec for:2, 黑黑
# Canot find vec for:3, 黑黑的
# Canot find vec for:2, 伸到
# Canot find vec for:4, 163K
# Canot find vec for:4, 操作失误
# Canot find vec for:2, 凉皮
# Canot find vec for:3, 肉夹馍
# Canot find vec for:2, 天冷
# Canot find vec for:2, 砂锅
# Canot find vec for:2, 臊子
# Canot find vec for:2, 会点
# Canot find vec for:4, 服务态度
# Canot find vec for:2, 挺快
# Canot find vec for:3, 朋友家
# Canot find vec for:2, 适中
# Canot find vec for:2, 结帐
# Canot find vec for:2, 上菜
# Canot find vec for:3, 几块钱
# Canot find vec for:3, 三四十
# Canot find vec for:2, 周到
# Canot find vec for:2, 家政
# Canot find vec for:2, 可上
# Canot find vec for:4, 上门服务
# Canot find vec for:2, 很轻
# Canot find vec for:2, 玩游
# Canot find vec for:2, 统还
# Canot find vec for:4, 系统维护
# Canot find vec for:3, 以免费
# Canot find vec for:2, 价廉
# Canot find vec for:4, 价廉物美
# Canot find vec for:2, 物美
# Canot find vec for:2, 不虚
# Canot find vec for:4, 不虚此行
# Canot find vec for:2, 吹牛
# Canot find vec for:4, 根本就是
# Canot find vec for:4, 市场营销
# Canot find vec for:2, 瞎吹
# Canot find vec for:2, 吹牛
# Canot find vec for:2, 屁大
# Canot find vec for:2, 大点
# Canot find vec for:3, 真不错
# Canot find vec for:2, 烤鱼
# Canot find vec for:2, 份量
# Canot find vec for:4, 等待时间
# Canot find vec for:3, 包装费
# Canot find vec for:2, 少点
# Canot find vec for:4, 顾不过来
# Canot find vec for:2, 三文
# Canot find vec for:2, 取用
# Canot find vec for:2, 繁多
# Canot find vec for:2, 哈根
# Canot find vec for:4, 哈根达斯
# Canot find vec for:2, 达斯
# Canot find vec for:3, 魏公村
# Canot find vec for:3, 好伦哥
# Canot find vec for:2, 龙口
# Canot find vec for:2, 东路
# Canot find vec for:2, 塞车
# Canot find vec for:2, 桌球
# Canot find vec for:3, 桌球台
# Canot find vec for:2, 球台
# Canot find vec for:2, 打翻
# Canot find vec for:2, 翻场
# Canot find vec for:2, 天突
# Canot find vec for:3, 几块钱
# Canot find vec for:3, 两三个
# Canot find vec for:2, 上菜
# Canot find vec for:6, hellip
# Canot find vec for:6, hellip
# Canot find vec for:6, hellip
# Canot find vec for:6, hellip
# Canot find vec for:2, 西餐
# Canot find vec for:3, 西餐厅
# Canot find vec for:2, 别处
# Canot find vec for:2, 太慢
# Canot find vec for:2, 配送
# Canot find vec for:2, 蜂鸟
# Canot find vec for:2, 配送
# Canot find vec for:2, 炸酱
# Canot find vec for:3, 炸酱面
# Canot find vec for:3, 火焰山
# Canot find vec for:2, 百般
# Canot find vec for:2, 不厌
# Canot find vec for:4, 不厌其烦
# Canot find vec for:2, 改图
# Canot find vec for:6, hellip
# Canot find vec for:6, hellip
# Canot find vec for:3, 装修工
# Canot find vec for:3, 购物网
# Canot find vec for:3, 信誉度
# Canot find vec for:3, 特色菜
# Canot find vec for:2, 半成
# Canot find vec for:3, 半成品
# Canot find vec for:2, 差劲
# Canot find vec for:6, hellip
# Canot find vec for:6, hellip
# Canot find vec for:3, 西瓜汁
# Canot find vec for:6, hellip
# Canot find vec for:6, hellip
# Canot find vec for:3, 西瓜子
# Canot find vec for:2, 扎进
# Canot find vec for:6, hellip
# Canot find vec for:6, hellip
# Canot find vec for:6, hellip
# Canot find vec for:6, hellip
# Canot find vec for:6, hellip
# Canot find vec for:6, hellip
# Canot find vec for:2, 结账
# Canot find vec for:3, 同一个
# Canot find vec for:2, 收银
# Canot find vec for:3, 收银台
# Canot find vec for:6, hellip
# Canot find vec for:6, hellip
# Canot find vec for:6, hellip
# Canot find vec for:6, hellip
# Canot find vec for:2, 收银
# Canot find vec for:3, 收银台
# Canot find vec for:6, hellip
# Canot find vec for:6, hellip
# Canot find vec for:6, hellip
# Canot find vec for:6, hellip
# Canot find vec for:3, 人情味
# Canot find vec for:2, 情味
# Canot find vec for:2, 融洽
# Canot find vec for:3, 生意人
# Canot find vec for:2, 想有
# Canot find vec for:2, 退让
# Canot find vec for:2, 大化
# Canot find vec for:3, 生意人
# Canot find vec for:2, 尽职
# Canot find vec for:4, 尽职尽责
# Canot find vec for:2, 尽责
# Canot find vec for:3, 羊肉汤
# Canot find vec for:2, 肉汤
# Canot find vec for:2, 血粉
# Canot find vec for:3, 粉丝汤
# Canot find vec for:4, 共同爱好
# Canot find vec for:2, 碰钉
# Canot find vec for:3, 碰钉子
# Canot find vec for:2, 钉子
# Canot find vec for:5, ldquo
# Canot find vec for:3, 串串香
# Canot find vec for:5, rdquo
# Canot find vec for:2, 竹签
# Canot find vec for:2, 蘸上
# Canot find vec for:4, 边走边吃
# Canot find vec for:2, 可坐
# Canot find vec for:2, 大锅
# Canot find vec for:2, 锅底
# Canot find vec for:2, 棒棒
# Canot find vec for:2, 结账
# Canot find vec for:2, 来作
# Canot find vec for:2, 榕树
# Canot find vec for:2, 建站
# Canot find vec for:3, 软件网
# Canot find vec for:3, 价比高
# Canot find vec for:2, 比高
# Canot find vec for:2, 单易
# Canot find vec for:2, 易用
# Canot find vec for:2, 升空
# Canot find vec for:2, 榕树
# Canot find vec for:2, 建站
# Canot find vec for:3, 软件网
# Canot find vec for:3, 物有所
# Canot find vec for:4, 物有所值
# Canot find vec for:2, 三合
# Canot find vec for:3, 三合一
# Canot find vec for:2, 开管
# Canot find vec for:2, 加到
# Canot find vec for:2, 炸酱
# Canot find vec for:3, 炸酱面
# Canot find vec for:2, 面食
# Canot find vec for:3, 一般般
# Canot find vec for:2, 般般
# Canot find vec for:3, 一般般
# Canot find vec for:2, 般般
# Canot find vec for:2, 越来
# Canot find vec for:2, 越来
# Canot find vec for:2, 热海
# Canot find vec for:2, 海参
# Canot find vec for:2, 三文
# Canot find vec for:3, 三文鱼
# Canot find vec for:2, 鱼骨
# Canot find vec for:2, 羊排
# Canot find vec for:6, hellip
# Canot find vec for:6, hellip
# Canot find vec for:2, 三文
# Canot find vec for:3, 三文鱼
# Canot find vec for:2, 鱼生
# Canot find vec for:2, 生冷
# Canot find vec for:2, 人浪
# Canot find vec for:2, 三文
# Canot find vec for:3, 三文鱼
# Canot find vec for:2, 海胆
# Canot find vec for:2, 少用
# Canot find vec for:3, 参考价
# Canot find vec for:4, 参考价值
# Canot find vec for:2, 配送
# Canot find vec for:3, 配送费
# Canot find vec for:2, 定会
# Canot find vec for:2, 大成
# Canot find vec for:2, 感兴
# Canot find vec for:6, hellip
# Canot find vec for:6, hellip
# Canot find vec for:2, 上菜
# Canot find vec for:2, 道菜
# Canot find vec for:2, 两口
# Canot find vec for:2, 烤鸭
# Canot find vec for:3, seo
# Canot find vec for:2, 上到
# Canot find vec for:3, 好几个
# Canot find vec for:4, 设计方案
# Canot find vec for:2, 订餐
# Canot find vec for:2, 续加
# Canot find vec for:2, 送达
# Canot find vec for:2, 订餐
# Canot find vec for:2, 开网
# Canot find vec for:2, 加到
# Canot find vec for:3, 购物车
# Canot find vec for:2, 不支
# Canot find vec for:4, 饿着肚子
# Canot find vec for:3, 速度慢
# Canot find vec for:3, 不多见
# Canot find vec for:2, 能感
# Canot find vec for:2, 菜店
# Canot find vec for:3, 吃不完
# Canot find vec for:2, 五分
# Canot find vec for:3, 整体感
# Canot find vec for:2, 中餐
# Canot find vec for:6, hellip
# Canot find vec for:6, hellip
# Canot find vec for:4, 服务周到
# Canot find vec for:2, 周到
# Canot find vec for:2, 香辣
# Canot find vec for:2, 清江
# Canot find vec for:3, 挺好吃
# Canot find vec for:2, 小块
# Canot find vec for:3, 优惠券
# Canot find vec for:4, 功能强大
# Canot find vec for:2, 咖喱
# Canot find vec for:3, 吃不完
# Canot find vec for:2, 少点
# Canot find vec for:2, 点菜
# Canot find vec for:2, 少点
# Canot find vec for:4, 重庆火锅
# Canot find vec for:3, 大鸭梨
# Canot find vec for:2, 鸭梨
# Canot find vec for:2, 种菜
# Canot find vec for:2, 菜色
# Canot find vec for:2, 越来
# Canot find vec for:2, 糊弄
# Canot find vec for:2, 作到
# Canot find vec for:2, 动工
# Canot find vec for:2, 面馆
# Canot find vec for:2, 婚宴
# Canot find vec for:2, 赶在
# Canot find vec for:2, 上菜
# Canot find vec for:2, 鸭梨
# Canot find vec for:3, 很多面
# Canot find vec for:2, 多面
# Canot find vec for:2, 拉面
# Canot find vec for:2, 刀削
# Canot find vec for:3, 刀削面
# Canot find vec for:2, 削面
# Canot find vec for:2, 虾子
# Canot find vec for:3, 担担面
# Canot find vec for:2, 板面
# Canot find vec for:2, 炸酱
# Canot find vec for:3, 炸酱面
# Canot find vec for:2, 包间
# Canot find vec for:2, 有生
# Canot find vec for:3, 生日歌
# Canot find vec for:2, 结账
# Canot find vec for:2, 大食
# Canot find vec for:2, 实相
# Canot find vec for:2, 狗屁
# Canot find vec for:2, 卖好
# Canot find vec for:3, 315
# Canot find vec for:2, 菜市
# Canot find vec for:3, 有效率
# Canot find vec for:2, 飞起
# Canot find vec for:2, 出好
# Canot find vec for:2, 近地
# Canot find vec for:2, 铁站
# Canot find vec for:2, 桥下
# Canot find vec for:2, 五分
# Canot find vec for:2, 路痴
# Canot find vec for:4, 比较丰富
# Canot find vec for:6, hellip
# Canot find vec for:2, 鸳鸯
# Canot find vec for:4, 一半一半
# Canot find vec for:2, 鸳鸯
# Canot find vec for:2, 不常
# Canot find vec for:2, 秋葵
# Canot find vec for:2, 汤锅
# Canot find vec for:2, 锅底
# Canot find vec for:3, 蔬菜类
# Canot find vec for:2, 菜叶
# Canot find vec for:2, 既往
# Canot find vec for:3, 惹不起
# Canot find vec for:3, 一般般
# Canot find vec for:2, 般般
# Canot find vec for:2, 订餐
# Canot find vec for:2, 退钱
# Canot find vec for:3, 收不到
# Canot find vec for:2, 常客
# Canot find vec for:3, 吃饺子
# Canot find vec for:2, 老边
# Canot find vec for:2, 退步
# Canot find vec for:3, 饺子皮
# Canot find vec for:2, 皮厚
# Canot find vec for:2, 馅儿
# Canot find vec for:3, 老字号
# Canot find vec for:2, 字号
# Canot find vec for:2, 烤鸭
# Canot find vec for:2, 锅盖
# Canot find vec for:2, 总店
# Canot find vec for:2, 锅盖
# Canot find vec for:2, 真多
# Canot find vec for:4, 古典风格
# Canot find vec for:2, 三文
# Canot find vec for:3, 三文鱼
# Canot find vec for:2, 家常
# Canot find vec for:3, 家常菜
# Canot find vec for:2, 大堂
# Canot find vec for:2, 很气
# Canot find vec for:2, 气派
# Canot find vec for:2, 货运
# Canot find vec for:2, 收货
# Canot find vec for:3, 收货人
# Canot find vec for:2, 货人
# Canot find vec for:3, 是否是
# Canot find vec for:2, 能变
# Canot find vec for:2, 变质
# Canot find vec for:2, 分发
# Canot find vec for:2, 货运
# Canot find vec for:2, 到货
# Canot find vec for:2, 货运
# Canot find vec for:4, 经营方式
# Canot find vec for:2, 西多
# Canot find vec for:2, 多口
# Canot find vec for:3, 好伦哥
# Canot find vec for:3, 吃一堑
# Canot find vec for:6, 吃一堑长一智
# Canot find vec for:3, 长一智
# Canot find vec for:2, 搞来
# Canot find vec for:4, 搞来搞去
# Canot find vec for:2, 折兵
# Canot find vec for:3, 水煮鱼
# Canot find vec for:2, 煮成
# Canot find vec for:4, 淡而无味
# Canot find vec for:2, 无味
# Canot find vec for:3, 会员卡
# Canot find vec for:2, 五份
# Canot find vec for:3, 马家堡
# Canot find vec for:2, 大成
# Canot find vec for:3, 串串香
# Canot find vec for:2, 香火
# Canot find vec for:3, 火锅店
# Canot find vec for:2, 够学
# Canot find vec for:2, 半套
# Canot find vec for:2, 烤鸭
# Canot find vec for:2, 小炒
# Canot find vec for:2, 鸭梨
# Canot find vec for:2, 锅底
# Canot find vec for:2, 鸳鸯
# Canot find vec for:3, 鸳鸯锅
# Canot find vec for:2, 辣得
# Canot find vec for:2, 光临
# Canot find vec for:2, 大成
# Canot find vec for:2, 华晨
# Canot find vec for:3, 毛血旺
# Canot find vec for:3, 一般般
# Canot find vec for:2, 般般
# Canot find vec for:4, 200+
# Canot find vec for:2, 不值
# Canot find vec for:2, 上菜
# Canot find vec for:2, 挺快
# Canot find vec for:2, 结账
# Canot find vec for:3, 服务费
# Canot find vec for:3, 十几块
# Canot find vec for:3, 几块钱
# Canot find vec for:2, 小费
# Canot find vec for:2, 后妈
# Canot find vec for:3, 哦哦哦
# Canot find vec for:2, 可控
# Canot find vec for:2, 收银
# Canot find vec for:3, 收银机
# Canot find vec for:3, 一个月
# Canot find vec for:2, 收银
# Canot find vec for:2, 互联
# Canot find vec for:2, 收银
# Canot find vec for:3, 收银机
# Canot find vec for:3, 一百元
# Canot find vec for:2, 百元
# Canot find vec for:3, 摆出来
# Canot find vec for:2, 快餐
# Canot find vec for:2, 快餐
# Canot find vec for:2, 业已
# Canot find vec for:2, 下在
# Canot find vec for:3, O2O
# Canot find vec for:4, 服务周到
# Canot find vec for:2, 周到
# Canot find vec for:2, 统还
# Canot find vec for:3, 以免费
# Canot find vec for:2, 受用
# Canot find vec for:2, 上菜
# Canot find vec for:2, 包房
# Canot find vec for:3, 没人管
# Canot find vec for:2, 极差
# Canot find vec for:2, 果盘
# Canot find vec for:2, 大城
# Canot find vec for:2, OA
# Canot find vec for:4, 服务态度
# Canot find vec for:3, 旅游网
# Canot find vec for:3, 电话卡
# Canot find vec for:2, 去日
# Canot find vec for:4, 多多关照
# Canot find vec for:2, 关照
# Canot find vec for:2, 披萨
# Canot find vec for:3, 料理店
# Canot find vec for:2, 三友
# Canot find vec for:2, 试听
# Canot find vec for:2, 一节
# Canot find vec for:3, 一节课
# Canot find vec for:2, 种菜
# Canot find vec for:2, 菜系
# Canot find vec for:4, 一技之长
# Canot find vec for:2, 之长
# Canot find vec for:2, 作准
# Canot find vec for:2, 三友
# Canot find vec for:3, 培训期
# Canot find vec for:2, 三友
# Canot find vec for:2, 配送
# Canot find vec for:2, 配送
# Canot find vec for:2, 份量
# Canot find vec for:3, 数一下
# Canot find vec for:2, 四双
# Canot find vec for:2, 约法
# Canot find vec for:2, 单间
# Canot find vec for:2, 上菜
# Canot find vec for:2, 扣肉
# Canot find vec for:2, 西都
# Canot find vec for:2, 还以
# Canot find vec for:2, 腊肉
# Canot find vec for:2, 急火
# Canot find vec for:3, 急火火
# Canot find vec for:2, 斤斤
# Canot find vec for:4, 斤斤计较
# Canot find vec for:2, 肯德
# Canot find vec for:3, 宅急送
# Canot find vec for:2, 急送
# Canot find vec for:2, 订餐
# Canot find vec for:2, 肯德
# Canot find vec for:3, 宅急送
# Canot find vec for:2, 急送
# Canot find vec for:2, 订餐
# Canot find vec for:2, 配送
# Canot find vec for:2, 肯德
# Canot find vec for:2, 太慢
# Canot find vec for:3, 狮子头
# Canot find vec for:2, 特价
# Canot find vec for:2, 烤鸭
# Canot find vec for:3, 水煮鱼
# Canot find vec for:2, 素菜
# Canot find vec for:2, 川口
# Canot find vec for:2, 谈笑
# Canot find vec for:4, 谈笑风生
# Canot find vec for:4, 千辛万苦
# Canot find vec for:2, 招标
# Canot find vec for:4, 技术支持
# Canot find vec for:2, 招标
# Canot find vec for:2, 招标
# Canot find vec for:2, 很顺
# Canot find vec for:2, 精湛
# Canot find vec for:2, 道菜
# Canot find vec for:4, 鱼香肉丝
# Canot find vec for:2, 香肉
# Canot find vec for:2, 肉丝
# Canot find vec for:2, 丝都
# Canot find vec for:2, 特好
# Canot find vec for:2, 薯条
# Canot find vec for:2, 有变
# Canot find vec for:2, 变脸
# Canot find vec for:4, 胡吃海喝
# Canot find vec for:2, 度外
# Canot find vec for:4, 深刻印象
# Canot find vec for:2, 刻印
# Canot find vec for:4, 服务态度
# Canot find vec for:4, 大同小异
# Canot find vec for:2, 小异
# Canot find vec for:2, 度外
# Canot find vec for:2, 续加
# Canot find vec for:4, 服务态度
# Canot find vec for:2, 肯德
# Canot find vec for:2, 三文
# Canot find vec for:3, 三文鱼
# Canot find vec for:2, 特好
# Canot find vec for:2, 巴洛
# Canot find vec for:3, 巴洛克
# Canot find vec for:2, 洛克
# Canot find vec for:4, 民国时期
# Canot find vec for:2, 哈尔
# Canot find vec for:3, 置身于
# Canot find vec for:4, 上个世纪
# Canot find vec for:3, 家属院
# Canot find vec for:2, 院里
# Canot find vec for:3, 让你能
# Canot find vec for:2, 长河
# Canot find vec for:4, 细细品味
# Canot find vec for:2, 未改
# Canot find vec for:4, 生活气息
# Canot find vec for:2, 活气
# Canot find vec for:2, 哈尔
# Canot find vec for:2, 低矮
# Canot find vec for:2, 开裂
# Canot find vec for:2, 外墙
# Canot find vec for:2, 油烟
# Canot find vec for:2, 烟熏
# Canot find vec for:2, 熏黑
# Canot find vec for:2, 加盖
# Canot find vec for:2, 门头
# Canot find vec for:4, 上个世纪
# Canot find vec for:3, 世纪末
# Canot find vec for:3, 居民区
# Canot find vec for:2, 后区
# Canot find vec for:2, 直开
# Canot find vec for:2, 顿觉
# Canot find vec for:3, 好开心
# Canot find vec for:2, 多美
# Canot find vec for:2, 既往
# Canot find vec for:2, 促销
# Canot find vec for:2, 新会
# Canot find vec for:3, 新会员
# Canot find vec for:2, 该会
# Canot find vec for:2, 上菜
# Canot find vec for:2, 很细
# Canot find vec for:2, 会教
# Canot find vec for:2, 凤爪
# Canot find vec for:2, 虎皮
# Canot find vec for:2, 凤爪
# Canot find vec for:2, 作工
# Canot find vec for:3, 辣椒酱
# Canot find vec for:3, 制作方
# Canot find vec for:4, 制作方法
# Canot find vec for:2, 会教
# Canot find vec for:4, 服务态度
# Canot find vec for:4, 得心应手
# Canot find vec for:2, 应手
# Canot find vec for:3, 美食网
# Canot find vec for:3, 让你在
# Canot find vec for:4, 价格优势
# Canot find vec for:4, 服务水平
# Canot find vec for:3, KFC
# Canot find vec for:2, 较繁
# Canot find vec for:2, 肯德
# Canot find vec for:2, 九鼎
# Canot find vec for:2, 配送
# Canot find vec for:3, 承包商
# Canot find vec for:2, 包商
# Canot find vec for:2, 三轮
# Canot find vec for:2, 送菜
# Canot find vec for:2, 越来
# Canot find vec for:2, 环球
# Canot find vec for:2, 太慢
# Canot find vec for:2, 上菜
# Canot find vec for:2, 哈根
# Canot find vec for:4, 哈根达斯
# Canot find vec for:2, 达斯
# Canot find vec for:3, 总体性
# Canot find vec for:2, 体性
# Canot find vec for:2, 既往
# Canot find vec for:2, 各样
# Canot find vec for:2, 派送
# Canot find vec for:2, 派送
# Canot find vec for:3, 老字号
# Canot find vec for:2, 字号
# Canot find vec for:2, 既往
# Canot find vec for:4, 服务到位
# Canot find vec for:3, 吃不起
# Canot find vec for:3, 转基因
# Canot find vec for:3, 大豆油
# Canot find vec for:2, 豆油
# Canot find vec for:2, 加林
# Canot find vec for:2, 出点
# Canot find vec for:3, 价比高
# Canot find vec for:2, 比高
# Canot find vec for:4, 比较丰富
# Canot find vec for:4, 品种齐全
# Canot find vec for:4, 服务态度
# Canot find vec for:3, 一个多
# Canot find vec for:4, 一个多月
# Canot find vec for:2, 实是
# Canot find vec for:3, SEO
# Canot find vec for:2, 越来
# Canot find vec for:2, 酸菜
# Canot find vec for:3, 酸菜鱼
# Canot find vec for:4, 服务态度
# Canot find vec for:3, 一般般
# Canot find vec for:2, 般般
# Canot find vec for:2, 清江
# Canot find vec for:3, 十一元
# Canot find vec for:2, 一元
# Canot find vec for:2, 不廉
# Canot find vec for:3, 跟不上
# Canot find vec for:2, 嘈杂
# Canot find vec for:3, 掌柜的
# Canot find vec for:2, 些小
# Canot find vec for:2, 小商
# Canot find vec for:4, 海报设计
# Canot find vec for:2, 谢客
# Canot find vec for:2, 烤鸭
# Canot find vec for:3, 购物网
# Canot find vec for:2, 酸辣
# Canot find vec for:2, 锅底
# Canot find vec for:2, 清汤
# Canot find vec for:3, 转基因
# Canot find vec for:2, 浸出
# Canot find vec for:3, 大豆油
# Canot find vec for:2, 豆油
# Canot find vec for:2, 川菜
# Canot find vec for:2, 供餐
# Canot find vec for:4, 服务态度
# Canot find vec for:2, 鳕鱼
# Canot find vec for:2, 寿司
# Canot find vec for:2, 没上
# Canot find vec for:2, 下回
# Canot find vec for:2, 上菜
# Canot find vec for:2, 友生
# Canot find vec for:2, 桌球
# Canot find vec for:3, 加盟商
# Canot find vec for:4, 签订合同
# Canot find vec for:3, 订合同
# Canot find vec for:2, 滑倒
# Canot find vec for:2, 踩到
# Canot find vec for:2, 物美
# Canot find vec for:4, 物美价廉
# Canot find vec for:2, 价廉
# Canot find vec for:2, 五花
# Canot find vec for:2, 说教
# Canot find vec for:2, 外行
# Canot find vec for:3, 教育网
# Canot find vec for:2, 能成
# Canot find vec for:2, 菜馆
# Canot find vec for:2, 常来
# Canot find vec for:2, 份量
# Canot find vec for:2, 实地
# Canot find vec for:4, 实地考察
# Canot find vec for:2, 小本
# Canot find vec for:4, 小本生意
# Canot find vec for:2, 本生
# Canot find vec for:2, 多餐
# Canot find vec for:2, 常来
# Canot find vec for:2, 常来
# Canot find vec for:3, 挺好吃
# Canot find vec for:2, 菜点
# Canot find vec for:2, 常来
# Canot find vec for:4, 餐饮行业
# Canot find vec for:4, 行业新闻
# Canot find vec for:2, 会同
# Canot find vec for:2, 大忙
# Canot find vec for:2, 实是
# Canot find vec for:5, mdash
# Canot find vec for:2, 搞成
# Canot find vec for:2, 爆满
# Canot find vec for:2, 香香
# Canot find vec for:3, 香香的
# Canot find vec for:3, 煲仔饭
# Canot find vec for:3, 煲仔饭
# Canot find vec for:2, 创始
# Canot find vec for:2, 作过
# Canot find vec for:2, 待人
# Canot find vec for:4, 有问必答
# Canot find vec for:2, 必答
# Canot find vec for:2, 接下
# Canot find vec for:4, 功能模块
# Canot find vec for:2, 揣摩
# Canot find vec for:4, 服务周到
# Canot find vec for:2, 周到
# Canot find vec for:4, 程序运行
# Canot find vec for:3, 稳定流
# Canot find vec for:2, 越来
# Canot find vec for:2, 西兰
# Canot find vec for:2, 福克
# Canot find vec for:3, 福克斯
# Canot find vec for:2, 克斯
# Canot find vec for:3, 斯冰川
# Canot find vec for:2, 冰川
# Canot find vec for:2, 跳伞
# Canot find vec for:2, 闲放
# Canot find vec for:2, 去处
# Canot find vec for:2, 客家
# Canot find vec for:3, 客家人
# Canot find vec for:3, 离家近
# Canot find vec for:2, 上菜
# Canot find vec for:2, 份量
# Canot find vec for:3, KTV
# Canot find vec for:3, 大大的
# Canot find vec for:4, 管理人员
# Canot find vec for:3, 营业额
# Canot find vec for:3, 吃不完
# Canot find vec for:4, 简简单单
# Canot find vec for:2, 上档
# Canot find vec for:3, 上档次
# Canot find vec for:2, 家产
# Canot find vec for:2, 餐盒
# Canot find vec for:2, 配送
# Canot find vec for:3, 配送费
# Canot find vec for:2, 配送
# Canot find vec for:2, 自取
# Canot find vec for:2, 餐盒
# Canot find vec for:5, trade
# Canot find vec for:2, 不装
# Canot find vec for:2, 饭盒
# Canot find vec for:2, 盒里
# Canot find vec for:2, 越来
# Canot find vec for:5, ldquo
# Canot find vec for:5, rdquo
# Canot find vec for:2, 订餐
# Canot find vec for:2, 立于
# Canot find vec for:2, 张旭
# Canot find vec for:2, 隶属
# Canot find vec for:3, 隶属于
# Canot find vec for:2, 拉扎
# Canot find vec for:2, 刺身
# Canot find vec for:3, 西瓜汁
# Canot find vec for:3, 黄瓜汁
# Canot find vec for:3, 羊肉串
# Canot find vec for:2, 池里
# Canot find vec for:2, 鲍鱼
# Canot find vec for:4, 服务质量
# Canot find vec for:3, 跟不上
# Canot find vec for:2, 能手
# Canot find vec for:2, 西都
# Canot find vec for:3, 多一些
# Canot find vec for:2, 烤鸭
# Canot find vec for:2, 铁板
# Canot find vec for:3, 全家福
# Canot find vec for:2, 福大
# Canot find vec for:2, 大部
# Canot find vec for:2, 鱼丸
# Canot find vec for:2, 不值
# Canot find vec for:2, 宫保
# Canot find vec for:3, 宫保鸡
# Canot find vec for:2, 鸡丁
# Canot find vec for:3, 一个角
# Canot find vec for:2, 角儿
# Canot find vec for:3, 多点儿
# Canot find vec for:3, 炸丸子
# Canot find vec for:2, 丸子
# Canot find vec for:2, 太软
# Canot find vec for:2, 一成
# Canot find vec for:2, 包菜
# Canot find vec for:4, 产品种类
# Canot find vec for:3, 回头客
# Canot find vec for:2, 既往
# Canot find vec for:2, 会点
# Canot find vec for:2, 肯德
# Canot find vec for:3, 二十分
# Canot find vec for:3, 送过来
# Canot find vec for:2, 相符
# Canot find vec for:2, 太棒
# Canot find vec for:3, 太棒了
# Canot find vec for:2, 多餐
# Canot find vec for:2, 跨区
# Canot find vec for:3, 加一点
# Canot find vec for:3, 送餐费
# Canot find vec for:2, 餐费
# Canot find vec for:3, 会员价
# Canot find vec for:4, 再好不过
# Canot find vec for:2, 铁西
# Canot find vec for:2, 烤鸭
# Canot find vec for:3, 记不清
# Canot find vec for:2, 借记
# Canot find vec for:2, 紫荆
# Canot find vec for:3, 紫荆山
# Canot find vec for:2, 荆山
# Canot find vec for:3, 大鸭梨
# Canot find vec for:2, 鸭梨
# Canot find vec for:2, 接电
# Canot find vec for:3, 接电话
# Canot find vec for:2, 台语
# Canot find vec for:3, 离家近
# Canot find vec for:2, 烤鸭
# Canot find vec for:3, 土豆丝
# Canot find vec for:2, 豆丝
# Canot find vec for:2, 两口
# Canot find vec for:2, 家常
# Canot find vec for:2, 费多
# Canot find vec for:4, 态度强硬
# Canot find vec for:2, 和服
# Canot find vec for:3, 以免费
# Canot find vec for:2, 卖菜
# Canot find vec for:2, 送电
# Canot find vec for:2, 订餐
# Canot find vec for:2, 配送
# Canot find vec for:3, 一般般
# Canot find vec for:2, 般般
# Canot find vec for:2, 烤鸭
# Canot find vec for:3, 消费型
# Canot find vec for:2, 家常
# Canot find vec for:3, 家常菜
# Canot find vec for:6, hellip
# Canot find vec for:2, 幽雅
# Canot find vec for:2, 上菜
# Canot find vec for:3, 添加剂
# Canot find vec for:2, 加剂
# Canot find vec for:3, 茶餐厅
# Canot find vec for:2, 装设
# Canot find vec for:5, mdash
# Canot find vec for:2, 三张
# Canot find vec for:2, 差劲
# Canot find vec for:2, 注上
# Canot find vec for:2, 上菜
# Canot find vec for:3, APP
# Canot find vec for:2, 度外
# Canot find vec for:4, 耽误时间
# Canot find vec for:2, 误时
# Canot find vec for:2, 度外
# Canot find vec for:4, 服务态度
# Canot find vec for:2, 方人
# Canot find vec for:2, 既往
# Canot find vec for:2, 繁多
# Canot find vec for:2, 友非
# Canot find vec for:4, 服务到位
# Canot find vec for:2, 果盘
# Canot find vec for:2, 盘里
# Canot find vec for:2, 一整
# Canot find vec for:2, 肯德
# Canot find vec for:4, 新奥尔良
# Canot find vec for:3, 奥尔良
# Canot find vec for:2, 肯德
# Canot find vec for:3, 宅急送
# Canot find vec for:2, 急送
# Canot find vec for:3, 宅急送
# Canot find vec for:2, 急送
# Canot find vec for:2, 面嫩
# Canot find vec for:2, 嫩嫩
# Canot find vec for:3, 嫩嫩的
# Canot find vec for:2, 吃起
# Canot find vec for:2, 前晚
# Canot find vec for:4, 强烈建议
# Canot find vec for:4, 失而复得
# Canot find vec for:2, 而复
# Canot find vec for:2, 复得
# Canot find vec for:2, 多美
# Canot find vec for:2, 既往
# Canot find vec for:3, 挺好吃
# Canot find vec for:2, 顿觉
# Canot find vec for:3, 好开心
# Canot find vec for:2, 越来
# Canot find vec for:2, 宫保
# Canot find vec for:3, 宫保鸡
# Canot find vec for:2, 鸡丁
# Canot find vec for:2, 吃出
# Canot find vec for:6, hellip
# Canot find vec for:6, hellip
# Canot find vec for:2, 上菜
# Canot find vec for:2, 如以
# Canot find vec for:2, 合家
# Canot find vec for:4, 家庭聚会
# Canot find vec for:2, 配送
# Canot find vec for:2, 配送
# Canot find vec for:2, 风里
# Canot find vec for:3, 风里来
# Canot find vec for:6, 风里来雨里去
# Canot find vec for:2, 里来
# Canot find vec for:2, 换口
# Canot find vec for:3, 换口味
# Canot find vec for:2, 宝岛
# Canot find vec for:2, 剩菜
# Canot find vec for:2, 耳根
# Canot find vec for:3, 好几种
# Canot find vec for:3, 看上去
# Canot find vec for:2, 吃起
# Canot find vec for:3, 看上去
# Canot find vec for:2, 越来
# Canot find vec for:2, 原材
# Canot find vec for:2, 素菜
# Canot find vec for:2, 没味
# Canot find vec for:2, 加料
# Canot find vec for:2, 越来
# Canot find vec for:2, 不值
# Canot find vec for:3, 自助餐
# Canot find vec for:3, 信息量
# Canot find vec for:2, 小礼
# Canot find vec for:2, 不吝
# Canot find vec for:2, 吝惜
# Canot find vec for:4, 再接再励
# Canot find vec for:2, 造福
# Canot find vec for:2, 香草
# Canot find vec for:2, 香草
# Canot find vec for:2, 原生
# Canot find vec for:4, 宫爆鸡丁
# Canot find vec for:2, 鸡丁
# Canot find vec for:2, 蓝莓
# Canot find vec for:2, 鸭蛋
# Canot find vec for:2, 热菜
# Canot find vec for:4, 一抢而空
# Canot find vec for:3, 越做越
# Canot find vec for:6, middot
# Canot find vec for:6, middot
# Canot find vec for:6, middot
# Canot find vec for:6, middot
# Canot find vec for:2, 没剩
# Canot find vec for:3, 速度慢
# Canot find vec for:2, 改改
# Canot find vec for:2, 避避
# Canot find vec for:2, 避暑
# Canot find vec for:2, 调给
# Canot find vec for:2, 蒸笼
# Canot find vec for:3, 自助餐
# Canot find vec for:2, 84
# Canot find vec for:2, 份量
# Canot find vec for:2, 烤鸭
# Canot find vec for:3, 中国化
# Canot find vec for:2, 化做
# Canot find vec for:3, 吃饺子
# Canot find vec for:2, 烤鸭
# Canot find vec for:3, 甜面酱
# Canot find vec for:2, 面酱
# Canot find vec for:2, 大葱
# Canot find vec for:2, 肯德
# Canot find vec for:2, 肯德
# Canot find vec for:2, 肯德
# Canot find vec for:2, 互联
# Canot find vec for:2, 明智
# Canot find vec for:3, 不定期
# Canot find vec for:2, 新会
# Canot find vec for:3, 新会员
# Canot find vec for:3, 会员卡
# Canot find vec for:2, 送货
# Canot find vec for:2, 挺快
# Canot find vec for:2, 点过
# Canot find vec for:2, 专人
# Canot find vec for:2, 包间
# Canot find vec for:3, 第一回
# Canot find vec for:4, 民族特色
# Canot find vec for:2, 好喝
# Canot find vec for:2, 上菜
# Canot find vec for:4, 功能强大
# Canot find vec for:2, 有数
# 2018-12-31 20:37:23,592 utils.py[531] INFO saving Word2VecKeyedVectors object under ./output/mini.kv, separately None
# 2018-12-31 20:37:23,601 utils.py[635] INFO not storing attribute vectors_norm
# 2018-12-31 20:37:23,604 smart_open_lib.py[176] DEBUG {'kw': {}, 'mode': 'wb', 'uri': './output/mini.kv'}
# 2018-12-31 20:37:23,677 utils.py[544] INFO saved ./output/mini.kv
# Canot find vec for:2, 实是
# Canot find vec for:2, 必胜
# Canot find vec for:3, 必胜客
# Canot find vec for:2, 必胜
# Canot find vec for:3, 必胜客
# Canot find vec for:2, 快餐
# Canot find vec for:2, 搞活
# Canot find vec for:2, 订餐
# Canot find vec for:2, 上菜
# Canot find vec for:4, 热情周到
# Canot find vec for:2, 周到
# Canot find vec for:3, APP
# Canot find vec for:3, 叫外卖
# Canot find vec for:2, 单系
# Canot find vec for:4, 服务态度
# Canot find vec for:2, 上菜
# Canot find vec for:2, 挺快
# Canot find vec for:3, 太好了
# Canot find vec for:2, 肯德
# Canot find vec for:2, 炸鸡
# Canot find vec for:4, 优惠活动
# Canot find vec for:2, 原味
# Canot find vec for:2, 送款
# Canot find vec for:2, 烤鸡
# Canot find vec for:2, 鸡翅
# Canot find vec for:2, 用纸
# Canot find vec for:2, 纸袋
# Canot find vec for:2, 袋装
# Canot find vec for:2, 纸袋
# Canot find vec for:2, 鸡皮
# Canot find vec for:2, 黏住
# Canot find vec for:2, 纸袋

# %%
mini.vocab.keys()
# Out:
# dict_keys(['买', '这套', '系统', '本来', '是用', '用来', '来做', '我们', '公司', '的', '公众', '公众号', '第三', '第三方', '平台', '运营', '没想', '没想到', '想到', '还有', 'app', '而且', '每个', '都很', '很方便', '方便', '管理', '是我', '我找', '找了', '很久', '的一', '一套', '程序', '还是', '是不', '不错', '别的', '菜', '没什么', '什么', '特殊', '使用', '说明', '看不', '看不懂', '不懂', '不会', '会用', '很多', '操作', '详细', '越来越', '不好', '好了', '菜品', '也', '少了', '服务', '也不', '不及', '及时', '是在', '不知', '不知道', '知道', '吃什么', '什么好', '就来', '来了', '跟', '这家', '家公司', '合作', '过一', '一次', '功能', '很强', '强大', '运行', '流畅', '很不', '很不错', '点的', '的中', '但是', '平时', '店里', '吃的', '可能', '外卖', '比', '直接', '花的', '时间', '时间长', '出来', '了的', '缘故', '吧', '味道', '是一', '是一样的', '一样', '样的', '好', '下次', '卖点', '试试', '满意', '速度', '真的', '的是', '是个', '预计', '毫不', '不差', '好评', '的确', '专业', '用心', '出品', '方面', '给', '还不', '有机', '有机会', '机会', '还来', '哈哈', '哈哈哈', '还', '品种', '齐全', '很快', '也不错', '态度', '感觉', '不过', '卫生', '过年', '当', '加了', '这个', '就是', '就是我', '需要', '要的', '感谢', '感谢你', '你们', '解决', '我的', '问题', '有新', '办理', '我还', '还会', '会来', '麻烦', '们的', '总体', '海鲜', '太少', '希望', '可以', '多一', '一些', '就在', '旁边', '边上', '上班', '这里', '已经', '已经成为', '成为', '为我', '食堂', '之意', '口味', '也很', '热情', '环境', '一直', '都是', '家的', '品质', '一直保持', '保持', '继续', '光顾', '下去', '超', '了', '有个', '免费', '经济', '实惠', '好吃', '吃不', '不贵', '也是', '没得', '最爱', '爱的', '一家', '性价比', '超高', '非常', '新鲜', '漂亮', '价位', '高了', '努力', '提高', '路上', '上的', '的那', '那个', '多了', '各种', '东西', '都', '少', '挺好', '挺好的', '好的', '有一', '单一', '水果', '服务员', '开心', '心的', '吃货', '餐饮', '软件', '在我', '那么', '那么多', '中', '最容易', '容易', '上手', '手艺', '吃过', '过了', '速度快', '说是', '香味', '加的', '很好', '很好吃', '哦', '可口', '我上', '那边', '时候', '中午', '就会', '会去', '去吃', '有点', '点点', '走路', '20', '分钟', '我很', '只要', '要上', '才会', '会选择', '选择', '他们', '哪个', '都不', '都不好', '不好吃', '特别', '失望', '在中', '中华', '推广', '什么样', '联系', '客服', '品味', '没有', '任何', '价格', '现如今', '如今', '能够', '做成', '这样', '错了', '网站', '的信', '信息', '更新', '内容', '来源', '真实', '优化', '方案', '都不错', '呢', '给力', '现在', '排名', '上升', '快了', '相信', '几天', '天都', '首页', '没问题', '再好', '好一', '好一点', '一点', '点就', '就可', '可以了', '好几', '几个', '站在', '在那', '那儿', '没事', '叫了', '几声', '都没', '没人', '希望能', '改善', '多次', '在', '自助', '比较', '比较高', '较高', '高的', '以前', '有的', '坑', '点了', '了一', '一个', '小的', '盘子', '进去', '还没', '多少', '人了', '山药', '上来', '来一', '一般', '只有', '片', '说', '主打', '文字', '游戏', '啊', '流量', '角度', '而言', '但', '有待', '提升', '虾', '限量', '的不', '比较喜欢', '喜欢', '会', '支持', '串串', '极了', '以后', '后会', '经常', '关注', '世家', '镇江', '特色', '面条', '产品', '种类', '我开', '设备', '原料', '从他', '购买', '买的', '空调', '不足', '老板', '掀开', '开了', '受不了', '不了', '东方', '对我', '咖啡', '咖啡馆', '墙面', '整体', '空间', '色彩', '搭配', '下面', '面的', '评价', '托', '教', '根本', '根本不', '和我', '差距', '很大', '骗人', '全家', '聚餐', '十几', '几个人', '个人', '总觉得', '觉得', '觉得好', '得好', '好像', '换', '厨师', '有好', '不如', '前去', '有些', '做', '又', '改进', '过节', '营业', '就不', '只是', '招牌', '没有了', '有了', '遗憾', '都吃', '不出', '舌头', '麻木', '就', '剩', '肯德基', '你', '啥时候', '能把', '把握', '把握好', '食品', '性的', '爆出', '很少', '吃了', '真心', '不是', '健康', '非常不错', '餐厅', '去', '当天', '挺多', '排', '半天', '微微', '非常好', '大家', '都能', '能接受', '接受', '选', '都说', '麻', '到位', '师傅', '五个', '两人', '没一', '个好', '架子', '哎', '因为', '所以', '专注', '超级', '刚刚', '刚刚开始', '开始', '效果', '效果图', '让我', '装修', '修好', '更让', '欢喜', '便宜', '发展', '相当', '可观', '挺不错', '成本', '加盟', '轻松', '无忧', '性价比高', '不怎么', '不怎么样', '怎么', '怎么样', '都做', '成了', '黑色', '也都', '极其', '其一', '的可', '可怜', '2', '孩子', '吃完', '完了', '想', '溜达', '椅子', '墙', '过不去', '不去', '差的', '很', '餐具', '要了', '几次', '茶水', '第一', '第一次', '送来', '后来', '再加', '加水', '自己', '动手', '我是', '个小', '小店', '店面', '又想', '想多', '多加', '就去', '去学', '学了', '和', '老师', '技术', '特别好', '别有', '耐心', '之后', '做出', '做出来', '确实', '有', '的人', '培训', '不一', '不一样', '后面', '巩固', '新的', '很有', '想法', '当下', '流行', '流行的', '行的', '风格', '都会', '加上', '每次', '朋友', '食材', '优雅', '朋友们', '很满意', '说了', '四个', '四个人', '啤酒', '喝了', '3', '具体', '不记得', '记得', '得了', '多', '再去', '都还没', '熟悉', '起来', '指导', '一下', '饭菜', '质量', '质量好', '那里', '消费', '在家', '在家里', '家里', '对面', '吃', '吃饭', '活动', '一份', '建议', '里面', '花椒', '如一', '最为', '工作', '认真', '这点', '难得', '的话', '还好', '要是', '企业', '能做', '能做到', '做到', '像你', '那我', '做生意', '生意', '不需', '不需要', '再', '作为', '忠实', '粉丝', '是最', '最好', '最好吃', '相同', '总是', '很喜欢 ...

# %%
from gensim.models import KeyedVectors
word_vectors = KeyedVectors.load(fname, mmap='r')
word_vectors.similar_by_word('系统')
# Out:
# 2018-12-31 17:55:28,151 utils.py[415] INFO loading Word2VecKeyedVectors object from ./output/mini.kv
# 2018-12-31 17:55:28,156 smart_open_lib.py[176] DEBUG {'kw': {}, 'mode': 'rb', 'uri': './output/mini.kv'}
# 2018-12-31 17:55:28,185 utils.py[484] INFO setting ignored attribute vectors_norm to None
# 2018-12-31 17:55:28,187 utils.py[421] INFO loaded ./output/mini.kv
# 2018-12-31 17:55:28,191 keyedvectors.py[1358] INFO precomputing L2-norms of word weight vectors
# /Users/lali2/dev/python/anaconda3/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('功能', 0.7172309160232544),
#  ('模块', 0.7166910171508789),
#  ('设备', 0.6992197036743164),
#  ('智能', 0.6782375574111938),
#  ('软件', 0.6644343137741089),
#  ('程序', 0.661666989326477),
#  ('优化', 0.6489428281784058),
#  ('技术', 0.6255435943603516),
#  ('界面', 0.6241154670715332),
#  ('自动', 0.6087337732315063)]

# %%
gen_mini_embedding(embed, mini, test_file )
len(mini)

# %%
from gensim.models import KeyedVectors
KeyedVectors.load?
# Out:
# 2018-12-31 17:26:20,475 textcleaner.py[37] INFO 'pattern' package not found; tag filters are not available for English

# %%
from file_cache.utils.util_date import timed
@timed()
def test():
    import gensim
    
    wv_from_text = gensim.models.KeyedVectors.load_word2vec_format(word2vec_model,binary=False)
    print(len(wv_from_text.vocab))
    
test()

# %%
print(wv_from_text.vocab.keys() )

# %%
dir(wv_from_text)

# %%
test= pd.read_csv(test_file, encoding='gb18030', delimiter='\t', header=None)


test.shape
# Out:
# (35157, 3)

# %%
import math
math.ceil(2.3)
# Out:
# 3

# %%
ceil(2.01)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-a0d755a4329a> in <module>()
# ----> 1 ceil(2.01)
#
# NameError: name 'ceil' is not defined

# %%
fname = "./output/mini_v6.txt"
import gensim
word_vectors = gensim.models.KeyedVectors.load_word2vec_format(word2vec_model, binary=False)
word_vectors.similar_by_word('探望')
# Out:
# 2019-01-04 23:15:06,879 utils_any2vec.py[170] INFO loading projection weights from ./input/Tencent_AILab_ChineseEmbedding/Tencent_AILab_ChineseEmbedding_mini.txt
# 2019-01-04 23:15:06,890 smart_open_lib.py[176] DEBUG {'kw': {}, 'mode': 'rb', 'uri': './input/Tencent_AILab_ChineseEmbedding/Tencent_AILab_ChineseEmbedding_mini.txt'}
# 2019-01-04 23:15:10,343 utils_any2vec.py[232] INFO loaded (20000, 200) matrix from ./input/Tencent_AILab_ChineseEmbedding/Tencent_AILab_ChineseEmbedding_mini.txt
# 2019-01-04 23:15:10,484 keyedvectors.py[1360] INFO precomputing L2-norms of word weight vectors
# /Users/lali2/dev/python/anaconda3/lib/python3.6/site-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('看望', 0.9192631244659424),
#  ('拜访', 0.7015642523765564),
#  ('慰问', 0.7004474401473999),
#  ('病了', 0.6374185085296631),
#  ('带他', 0.6350953578948975),
#  ('去见', 0.6199995875358582),
#  ('陪同', 0.6194216012954712),
#  ('请假', 0.6167483329772949),
#  ('照顾', 0.6102991104125977),
#  ('前去', 0.6005936861038208)]

# %%
word_vectors['探望']
# Out:
# array([ 0.21461999,  0.139884  ,  0.391754  ,  0.231987  ,  0.11961   ,
#        -0.31259799, -0.102125  ,  0.020797  ,  0.361761  , -0.09875   ,
#        -0.047344  ,  0.12978899,  0.219998  , -0.407498  ,  0.161724  ,
#        -0.118959  , -0.19262899, -0.294972  , -0.136594  , -0.199864  ,
#         0.082437  ,  0.378111  ,  0.022619  ,  0.093166  ,  0.104366  ,
#         0.57152098, -0.243688  ,  0.44615701,  0.35987699,  0.052411  ,
#        -0.06698   ,  0.102023  ,  0.17807201,  0.049176  , -0.30131701,
#        -0.044619  ,  0.053053  ,  0.23609   , -0.085294  , -0.035479  ,
#         0.33512801, -0.32636601, -0.090003  ,  0.74466902, -0.34595901,
#        -0.213992  , -0.287085  , -0.38124299,  0.087105  ,  0.069898  ,
#        -0.175255  , -0.23327801, -0.17242301,  0.10459   ,  0.283894  ,
#         0.35463399,  0.032908  ,  0.140956  , -0.14814   ,  0.204862  ,
#        -0.186671  ,  0.242083  ,  0.620884  ,  0.150089  ,  0.072815  ,
#        -0.047854  , -0.078099  , -0.216561  , -0.16214199, -0.011308  ,
#        -0.76299602, -0.124233  ,  0.127123  ,  0.445678  , -0.0127    ,
#         0.008824  ,  0.34380701, -0.14496499, -0.13401499,  0.32193401,
#         0.113197  ,  0.022872  , -0.057701  ,  0.68145001, -0.31311199,
#         0.001493  ,  0.197529  , -0.012771  , -0.009035  ,  0.19881301,
#         0.128235  ,  0.048779  ,  0.317918  , -0.186882  ,  0.006798  ,
#         0.053179  ,  0.118678  , -0.148397  , -0.070585  , -0.230141  ,
#        -0.35302901, -0.024326  , -0.16343901, -0.067331  , -0.30037299,
#         0.209197  ,  0.039434  , -0.360569  ,  0.42813501, -0.070241  ,
#         0.101072  ,  0.145795  , -0.36316901,  0.18881699,  0.154864  ,
#         0.06418   , -0.077153  , -0.283427  , -0.068774  , -0.122014  ,
#         0.108701  ,  0.024629  , -0.164759  , -0.097373  ,  0.161753  ,
#         0.40039599, -0.387667  , -0.077576  , -0.30177301, -0.30057499,
#         0.30184799,  0.23830999,  0.011117  ,  0.141876  , -0.26592499,
#        -0.450643  , -0.093379  , -0.047365  , -0.47402999, -0.037783  ,
#        -0.024907  ,  0.080771  , -0.75897998, -0.112935  , -0.182023  ,
#        -0.011752  ,  0.170578  ,  0.136287  , -0.045986  , -0.26457399,
#        -0.28468999, -0.45607799, -0.18557499,  0.227772  , -0.42705101,
#         0.32336801, -0.0069    , -0.003334  ,  0.58223403, -0.18494201,
#        -0.114188  ,  0.21439201,  0.52515501, -0.170885  ,  0.32058901,
#        -0.021454  ,  0.079907  ,  0.56472999,  0.41753301, -0.00219   ,
#         0.45133901,  0.24022201, -0.2033    ,  0.12175   , -0.053368  ,
#        -0.431225  ,  0.216268  , -0.55503702,  0.26481599,  0.041348  ,
#         0.27290499, -0.39300701, -0.50160599, -0.090904  ,  0.013922  ,
#         0.080536  , -0.101174  ,  0.207017  ,  0.036583  , -0.39998701,
#         0.149297  ,  0.030457  , -0.161488  ,  0.24650501,  0.36559299,
#         0.356233  , -0.60016501, -0.61094803, -0.67590499, -0.070546  ])

# %%
word_vectors.wv.vocab.keys()
# Out:
# /Users/lali2/dev/python/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   """Entry point for launching an IPython kernel.
# dict_keys(['!', '#', '#13', '#14', '#313#', '#315#', '#60616263', '#__&', '#___#', '$', '%', '&', "'", '(', ')', '*', '+', '+%', '+&', '++', '+1', '+10086', '+11G', '+1GB', '+2', '+4', '+5G', '+88', '+Vx', '+_+', ',', '-', '.', '.&', '..', '...', '....', '.....', '......', '......&', '.......', '........', '.........', '..........', '...........', '............', '..............', '...............', '................', '.................', '..................', '...................', '....................', '.....................', '......................', '.......................', '........................', '..........................', '...........................', '.............................', '...................................', '.........................................', '..........................................................', '...__', '.._', '._', '/', '0', '0%', '0.01', '0.015', '0.02%', '0.025%', '0.05', '0.06%', '0.08', '0.11', '0.117', '0.2%', '0.24', '0.25%', '0.3', '0.3%', '0.35', '0.5', '0.5%', '0.52', '0.6', '0.7', '0.75', '0.75%', '0.8', '0.81', '0.83', '0.85', '00', '0000', '00000', '000000', '0000000', '00000000000000000', '00045', '001', '001153', '001305', '002', '003', '006611', '007', '01', '010', '0105ppmoney19', '012', '015', '0153', '02', '02.13', '02.15', '020', '02014', '025', '03', '0309', '036273', '04', '041928', '0440', '0444', '0476', '04816', '05', '05%', '055', '055162734677', '0571', '06', '068', '07', '0717', '075723632285', '08', '0808', '082', '09', '09.15', '09.19', '09.23', '098', '098CN', '0K', '0k', '1', '1%', '1+', '1+1', '1+3', '1+3+0+2+8+0+7+6+6+5+5', '1.0', '1.1', '1.11', '1.2', '1.23', '1.3', '1.31', '1.362', '1.4', '1.4%', '1.451', '1.5', '1.5%', '1.6', '1.60', '1.68%', '1.7', '1.76', '1.8', '1.89', '1.9', '1.9%', '10', '10%', '10.00', '10.1', '10.11', '10.12', '10.19', '10.2', '10.21', '10.27', '10.30', '10.31', '10.4', '10.5', '10.5%', '10.6', '10.8%', '100', '100%', '100.01', '1000', '10000', '100000', '1000739675637', '1000W', '1007', '1008', '10086', '10086+', '100M', '100V', '100W', '100g', '100w', '101', '1010', '10101234', '1013', '1018', '102', '103', '103.7', '1040', '105', '1050', '107', '108', '1080', '1086', '1088', '1089', '1099', '10Kg', '10W', '10w', '11', '11%', '11.00', '11.05', '11.11', '11.14', '11.15', '11.18', '11.19', '11.20', '11.21', '11.22', '11.24', '11.26', '11.29', '11.31', '11.32', '11.40', '11.43', '11.5', '11.5%', '11.9%', '110', '1100', '11000', '111', '111052', '1111', '112', '1123', '11231', '11231.28', '1124', '113', '1133', '114', '115', '1150', '1153', '1155', '116', '117', '1170330344351162', '118', '11999', '11G', '12', '12%', '12.02', '12.09', '12.14', '12.15', '12.16', '12.18', '12.21', '12.25', '12.45', '120', '120.00', '1200', '12000', '12000000', '120183582907', '1202393636820', '121', '12166', '122', '123', '12305', '12306', '12308', '12315', '1233', '12333', '1234', '12345', '12377', '124', '125', '1250', '1258082222', '126', '1260', '127', '12700', '1276', '128', '12800', '129', '1299', '13', '13%', '13.15', '13.1579', '13.20', '13.5', '13.50', '130', '130+', '1300', '13000', '13104', '1314', '13181135696', '132', '132+', '132.65', '133', '13321139654', '13397822765', '134', '134874', '135', '1350', '136', '1360', '1363', '1365', '13680', '1377', '138', '1380', '1388', '139', '139.129', '14', '14%', '14+6', '14.20', '14.5%', '14.7', '14.84%', '140', '1400', '14000', '14025', '1413161383389268', '144', '1440', '1442', '144830836', '145', '14500', '1455', '146', '147', '1479', '149174', '14980', '14kg', '14km', '15', '15%', '15.27', '15.3%', '15.5%', '15.6', '15.6%', '150', '150+', '1500', '1500+', '15000', '1500px', '150rmb', '151', '1520', '153', '1530', '155', '1560', '1564', '157', '157.8', '1579', '158', '1580', '158232', '1599', '15CBM', '16', '16#17#18#19#20#', '16%', '16.20', '16.5%', '16.8%', '160', '1600', '1600+RMB', '16000', '16000+', '1600893025780', '161', '1614960806127042', '1620', '163', '163.62%', '163K ...
